# %% [markdown]
# Defining  an  "adopted  user"   as  a  user  who   has  logged  into  the  product  on  three  separate
# days  in  at  least  one  seven­day  period ,  identify  which  factors  predict  future  user
# adoption .

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
users = pd.read_csv('takehome_users.csv')
users.head()
# Out:
#    object_id        creation_time               name  \
# 0          1  2014-04-22 03:53:30     Clausen August
# 1          2  2013-11-15 03:45:04      Poole Matthew
# 2          3  2013-03-19 23:14:52  Bottrill Mitchell
# 3          4  2013-05-21 08:09:28    Clausen Nicklas
# 4          5  2013-01-17 10:14:20          Raw Grace
#
#                         email creation_source  last_session_creation_time  \
# 0    AugustCClausen@yahoo.com    GUEST_INVITE                1.398139e+09
# 1      MatthewPoole@gustr.com      ORG_INVITE                1.396238e+09
# 2  MitchellBottrill@gustr.com      ORG_INVITE                1.363735e+09
# 3   NicklasSClausen@yahoo.com    GUEST_INVITE                1.369210e+09
# 4          GraceRaw@yahoo.com    GUEST_INVITE                1.358850e+09
#
#    opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# 0                         1                           0      11
# 1                         0                           0       1
# 2                         0                           0      94
# 3                         0                           0       1
# 4                         0                           0     193
#
#    invited_by_user_id
# 0             10803.0
# 1               316.0
# 2              1525.0
# 3              5151.0
# 4              5240.0

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   object_id                   12000 non-null  int64
#  1   creation_time               12000 non-null  object
#  2   name                        12000 non-null  object
#  3   email                       12000 non-null  object
#  4   creation_source             12000 non-null  object
#  5   last_session_creation_time  8823 non-null   float64
#  6   opted_in_to_mailing_list    12000 non-null  int64
#  7   enabled_for_marketing_drip  12000 non-null  int64
#  8   org_id                      12000 non-null  int64
#  9   invited_by_user_id          6417 non-null   float64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 937.6+ KB

# %%
users['creation_time'] = pd.to_datetime(users['creation_time'])
users.head()
# Out:
#    object_id       creation_time               name  \
# 0          1 2014-04-22 03:53:30     Clausen August
# 1          2 2013-11-15 03:45:04      Poole Matthew
# 2          3 2013-03-19 23:14:52  Bottrill Mitchell
# 3          4 2013-05-21 08:09:28    Clausen Nicklas
# 4          5 2013-01-17 10:14:20          Raw Grace
#
#                         email creation_source  last_session_creation_time  \
# 0    AugustCClausen@yahoo.com    GUEST_INVITE                1.398139e+09
# 1      MatthewPoole@gustr.com      ORG_INVITE                1.396238e+09
# 2  MitchellBottrill@gustr.com      ORG_INVITE                1.363735e+09
# 3   NicklasSClausen@yahoo.com    GUEST_INVITE                1.369210e+09
# 4          GraceRaw@yahoo.com    GUEST_INVITE                1.358850e+09
#
#    opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# 0                         1                           0      11
# 1                         0                           0       1
# 2                         0                           0      94
# 3                         0                           0       1
# 4                         0                           0     193
#
#    invited_by_user_id
# 0             10803.0
# 1               316.0
# 2              1525.0
# 3              5151.0
# 4              5240.0

# %%
never_used = np.where(users.last_session_creation_time.isna())
never_used_df = users.iloc[never_used]
never_used_df.head()
# Out:
#     object_id       creation_time               name  \
# 7           8 2013-07-31 05:34:02  Hamilton Danielle
# 8           9 2013-11-05 04:04:24         Amsel Paul
# 11         12 2014-04-17 23:48:38    Mathiesen L�rke
# 14         15 2013-07-16 21:33:54        Theiss Ralf
# 15         16 2013-02-11 10:09:50         Engel Ren�
#
#                          email    creation_source  last_session_creation_time  \
# 7   DanielleHamilton@yahoo.com  PERSONAL_PROJECTS                         NaN
# 8        PaulAmsel@hotmail.com  PERSONAL_PROJECTS                         NaN
# 11   LaerkeLMathiesen@cuvox.de         ORG_INVITE                         NaN
# 14      RalfTheiss@hotmail.com  PERSONAL_PROJECTS                         NaN
# 15       ReneEngel@hotmail.com  PERSONAL_PROJECTS                         NaN
#
#     opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# 7                          1                           1      74
# 8                          0                           0     302
# 11                         0                           0     130
# 14                         0                           0     175
# 15                         0                           0     211
#
#     invited_by_user_id
# 7                  NaN
# 8                  NaN
# 11              9270.0
# 14                 NaN
# 15                 NaN

# %%
never_used_df.creation_source.value_counts()
# Out:
# PERSONAL_PROJECTS    1347
# ORG_INVITE           1066
# GUEST_INVITE          575
# SIGNUP                189
# Name: creation_source, dtype: int64

# %%
engagement = pd.read_csv('takehome_user_engagement.csv')
engagement.head()
# Out:
#             time_stamp  user_id  visited
# 0  2014-04-22 03:53:30        1        1
# 1  2013-11-15 03:45:04        2        1
# 2  2013-11-29 03:45:04        2        1
# 3  2013-12-09 03:45:04        2        1
# 4  2013-12-25 03:45:04        2        1

# %%
engagement.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207917 entries, 0 to 207916
# Data columns (total 3 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   time_stamp  207917 non-null  object
#  1   user_id     207917 non-null  int64
#  2   visited     207917 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 4.8+ MB

# %%
engagement['time_stamp'] = pd.to_datetime(engagement['time_stamp'])
engagement.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207917 entries, 0 to 207916
# Data columns (total 3 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   time_stamp  207917 non-null  datetime64[ns]
#  1   user_id     207917 non-null  int64
#  2   visited     207917 non-null  int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 4.8 MB

# %%
total_visit = engagement.groupby('user_id').count()
total_visit.head()
# Out:
#          time_stamp  visited
# user_id
# 1                 1        1
# 2                14       14
# 3                 1        1
# 4                 1        1
# 5                 1        1

# %%
freq_visitors = total_visit.time_stamp[total_visit.time_stamp >= 3]
freq_visitors.head()
# Out:
# user_id
# 2      14
# 10    284
# 20      7
# 33     18
# 42    342
# Name: time_stamp, dtype: int64

# %%
most_freq_visits = engagement[engagement.user_id.isin(freq_visitors.index)]
most_freq_visits.head()
# Out:
#            time_stamp  user_id  visited
# 1 2013-11-15 03:45:04        2        1
# 2 2013-11-29 03:45:04        2        1
# 3 2013-12-09 03:45:04        2        1
# 4 2013-12-25 03:45:04        2        1
# 5 2013-12-31 03:45:04        2        1

# %%
#https://stackoverflow.com/questions/45281297/group-by-week-in-pandas/45281418
weekly_visits = most_freq_visits.groupby(['user_id', pd.Grouper(key='time_stamp', freq='W-MON')])['visited'].sum().reset_index().sort_values('time_stamp')
adopted_visitors = weekly_visits[weekly_visits['visited'] >= 3]
adopted_visitors.sort_values(by='user_id')
# Out:
#        user_id time_stamp  visited
# 46          10 2013-09-16        4
# 70          10 2014-03-03        7
# 61          10 2013-12-30        6
# 26          10 2013-04-29        3
# 75          10 2014-04-07        6
# ...        ...        ...      ...
# 61886    11975 2014-03-10        5
# 61918    11988 2014-05-26        5
# 61915    11988 2014-05-05        3
# 61917    11988 2014-05-19        4
# 61909    11988 2014-03-24        4
#
# [33742 rows x 3 columns]

# %%
users['adopted_user'] = 0
users['adopted_user'] = np.where(users.object_id.isin(adopted_visitors.user_id), 1, 0)
users.adopted_user.value_counts()
# Out:
# 0    10556
# 1     1444
# Name: adopted_user, dtype: int64

# %%
users.head(-11)
# Out:
#        object_id       creation_time               name  \
# 0              1 2014-04-22 03:53:30     Clausen August
# 1              2 2013-11-15 03:45:04      Poole Matthew
# 2              3 2013-03-19 23:14:52  Bottrill Mitchell
# 3              4 2013-05-21 08:09:28    Clausen Nicklas
# 4              5 2013-01-17 10:14:20          Raw Grace
# ...          ...                 ...                ...
# 11984      11985 2013-07-08 17:23:26   Jespersen Marcus
# 11985      11986 2012-06-24 01:02:14      Ribeiro Clara
# 11986      11987 2013-03-15 03:21:01         Reed Poppy
# 11987      11988 2014-03-15 11:04:47        Minick John
# 11988      11989 2013-09-02 11:24:33     Pereira Emilly
#
#                                  email     creation_source  \
# 0             AugustCClausen@yahoo.com        GUEST_INVITE
# 1               MatthewPoole@gustr.com          ORG_INVITE
# 2           MitchellBottrill@gustr.com          ORG_INVITE
# 3            NicklasSClausen@yahoo.com        GUEST_INVITE
# 4                   GraceRaw@yahoo.com        GUEST_INVITE
# ...                                ...                 ...
# 11984        MarcusTJespersen@cuvox.de   PERSONAL_PROJECTS
# 11985     ClaraBarrosRibeiro@gmail.com  SIGNUP_GOOGLE_AUTH
# 11986               ftdkorrj@uyhoy.com              SIGNUP
# 11987            JohnFMinick@yahoo.com   PERSONAL_PROJECTS
# 11988  EmillyOliveiraPereira@gmail.com  SIGNUP_GOOGLE_AUTH
#
#        last_session_creation_time  opted_in_to_mailing_list  \
# 0                    1.398139e+09                         1
# 1                    1.396238e+09                         0
# 2                    1.363735e+09                         0
# 3                    1.369210e+09                         0
# 4                    1.358850e+09                         0
# ...                           ...                       ...
# 11984                         NaN                         0
# 11985                1.341105e+09                         0
# 11986                1.363318e+09                         0
# 11987                1.401621e+09                         0
# 11988                1.378553e+09                         1
#
#        enabled_for_marketing_drip  org_id  invited_by_user_id  adopted_user
# 0                               0      11             10803.0             0
# 1                               0       1               316.0             0
# 2                               0      94              1525.0             0
# 3                               0       1              5151.0             0
# 4                               0     193              5240.0             0
# ...                           ...     ...                 ...           ...
# 11984                           0      74                 NaN             0
# 11985                           0     111                 NaN             0
# 11986                           0       1                 NaN             0
# 11987                           0     114                 NaN             1
# 11988                           0      22                 NaN             0
#
# [11989 rows x 11 columns]

# %%
users_source = ['PERSONAL_PROJECTS', 'GUEST_INVITE', 'ORG_INVITE', 'SIGNUP', 'SIGNUP_GOOGLE_AUTH']
users['creation_source'] = users.creation_source.replace(users_source, [0, 1, 2, 3, 4])
users.head()
# Out:
#    object_id       creation_time               name  \
# 0          1 2014-04-22 03:53:30     Clausen August
# 1          2 2013-11-15 03:45:04      Poole Matthew
# 2          3 2013-03-19 23:14:52  Bottrill Mitchell
# 3          4 2013-05-21 08:09:28    Clausen Nicklas
# 4          5 2013-01-17 10:14:20          Raw Grace
#
#                         email  creation_source  last_session_creation_time  \
# 0    AugustCClausen@yahoo.com                1                1.398139e+09
# 1      MatthewPoole@gustr.com                2                1.396238e+09
# 2  MitchellBottrill@gustr.com                2                1.363735e+09
# 3   NicklasSClausen@yahoo.com                1                1.369210e+09
# 4          GraceRaw@yahoo.com                1                1.358850e+09
#
#    opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# 0                         1                           0      11
# 1                         0                           0       1
# 2                         0                           0      94
# 3                         0                           0       1
# 4                         0                           0     193
#
#    invited_by_user_id  adopted_user
# 0             10803.0             0
# 1               316.0             0
# 2              1525.0             0
# 3              5151.0             0
# 4              5240.0             0

# %%
users.dropna(subset=['last_session_creation_time'], inplace=True)

# %%
users.fillna({'invited_by_user_id': 0}, inplace=True)
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8823 entries, 0 to 11999
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   object_id                   8823 non-null   int64
#  1   creation_time               8823 non-null   datetime64[ns]
#  2   name                        8823 non-null   object
#  3   email                       8823 non-null   object
#  4   creation_source             8823 non-null   int64
#  5   last_session_creation_time  8823 non-null   float64
#  6   opted_in_to_mailing_list    8823 non-null   int64
#  7   enabled_for_marketing_drip  8823 non-null   int64
#  8   org_id                      8823 non-null   int64
#  9   invited_by_user_id          8823 non-null   float64
#  10  adopted_user                8823 non-null   int32
# dtypes: datetime64[ns](1), float64(2), int32(1), int64(5), object(2)
# memory usage: 792.7+ KB

# %%
_ = sns.heatmap(users.corr(), annot=True)

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
y = users.adopted_user
X = users[['creation_source', 'last_session_creation_time', 'opted_in_to_mailing_list', 'enabled_for_marketing_drip', 'org_id','invited_by_user_id']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state = 123)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
params = [0.001, 0.01, 0.1, 1, 10, 100]

accuracies = {}

for i in params:
    lr = LogisticRegression(C= i, random_state= 123)
    lr.fit(X_train, y_train)
    
    y_lr_pred = lr.predict(X_test)
    
    acc_score = accuracy_score(y_test, y_lr_pred)
    accuracies[i] = acc_score
accuracies
# Out:
# {0.001: 0.8386219401631912,
#  0.01: 0.8386219401631912,
#  0.1: 0.8386219401631912,
#  1: 0.8386219401631912,
#  10: 0.8386219401631912,
#  100: 0.8386219401631912}

# %%
lr2 = LogisticRegression(C=0.1)
lr2.fit(X_train, y_train)

print(confusion_matrix(y_test, y_lr_pred))
print(lr2.score(X_test, y_test))
# Out:
# [[1850    0]
#  [ 356    0]]
# 0.8386219401631912

# %%
features = X
importances = list(lr2.coef_[0])
sort_import = np.sort(importances)

plt.figure(figsize=(10, 5))
index = [0, 1, 2, 3, 4, 5]
_ = plt.barh(index, sort_import, align='center')
plt.xlabel('Imporatance')
plt.yticks(index, features)
plt.ylabel('Features')
plt.title('Feature Importance Logistic Regression')
plt.show()

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
estimators = [10, 25, 50, 75, 100]

rf_scores = {}

for i in estimators:
    rf = RandomForestClassifier(n_estimators=i, criterion='entropy', random_state=123 )
    rf.fit(X_train, y_train)
    
    y_rf_predict = rf.predict(X_test)
    
    acc_rf_score = accuracy_score(y_test, y_rf_predict)
    rf_scores[i] = acc_rf_score
rf_scores
# Out:
# {10: 0.898458748866727,
#  25: 0.900725294650952,
#  50: 0.900725294650952,
#  75: 0.9016319129646418,
#  100: 0.8980054397098821}

# %%
rf2 = RandomForestClassifier(n_estimators=75, criterion='entropy', random_state=42)
rf2.fit(X_train, y_train)

print(confusion_matrix(y_test, y_rf_predict))
print(rf2.score(X_test, y_test))
# Out:
# [[1767   83]
#  [ 142  214]]
# 0.900271985494107

# %%
features = X
importances = list(rf2.feature_importances_)
sort_import = np.sort(importances)

plt.figure(figsize=(10, 5))
index = [0, 1, 2, 3, 4, 5]
_ = plt.barh(index, sort_import, align='center')
plt.xlabel('Imporatance')
plt.yticks(index, features)
plt.ylabel('Features')
plt.title('Feature Importance Random Forest')
plt.show()

# %% [markdown]
# # Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gb = GradientBoostingClassifier()
gb.fit(X_train, y_train)

y_gb_predict = gb.predict(X_test)

print(confusion_matrix(y_test, y_gb_predict))
print(gb.score(X_test, y_test))
# Out:
# [[1756   94]
#  [ 136  220]]
# 0.8957388939256573

# %%
features = X
importances = list(gb.feature_importances_)
sort_import = np.sort(importances)

plt.figure(figsize=(10, 5))
index = [0,1,2, 3, 4, 5]
_ = plt.barh(index, sort_import, align='center')
plt.xlabel('Imporatance')
plt.yticks(index, features)
plt.ylabel('Features')
plt.title('Feature Importance Gradient Boosting')
plt.show()
